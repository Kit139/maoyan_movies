# %%
import requests  

r = requests.get('https://zhangkaiheng.gitee.io/')
r.text
# Out:
# '<!DOCTYPE html><html lang="zh-CN" data-theme="light"><head><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width,initial-scale=1"><title>ç\x88±ç\x88¬è\x99«ä¸\x8eå¤§æ\x95°æ\x8d®</title><meta name="keywords" content="ç\x9f³å¤§"><meta name="author" content="Kit"><meta name="copyright" content="Kit"><meta name="format-detection" content="telephone=no"><meta name="theme-color" content="#ffffff"><meta http-equiv="Cache-Control" content="no-transform"><meta http-equiv="Cache-Control" content="no-siteapp"><meta name="description" content="ç\x9f³å¤§CITä¸ªäººå\xad¦ä¹\xa0å\x88\x86äº«"><meta property="og:type" content="website"><meta property="og:title" content="ç\x88±ç\x88¬è\x99«ä¸\x8eå¤§æ\x95°æ\x8d®"><meta property="og:url" content="https://zhangkaiheng.gitee.io/index.html"><meta property="og:site_name" content="ç\x88±ç\x88¬è\x99«ä¸\x8eå¤§æ\x95°æ\x8d®"><meta property="og:description" content="ç\x9f³å¤§CITä¸ªäººå\xad¦ä¹\xa0
# ...

# %%
import requests  

r = requests.get('http://httpbin.org/get')  
print(r.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.24.0",
#     "X-Amzn-Trace-Id": "Root=1-5ffafb15-359b0b77132659c70502c7d1"
#   },
#   "origin": "112.32.241.87",
#   "url": "http://httpbin.org/get"
# }

# %%
import requests  

data = {  
    'name': 'kit',  
    'age': 19
}  
r = requests.get('http://httpbin.org/get', params=data) 
print(r.text)
# Out:
# {
#   "args": {
#     "age": "19",
#     "name": "kit"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.24.0",
#     "X-Amzn-Trace-Id": "Root=1-5ffafb50-233e6bcd3d46f1311e9fc9cb"
#   },
#   "origin": "112.32.241.87",
#   "url": "http://httpbin.org/get?name=kit&age=19"
# }

# %%
def ping(i):
    return i*2

ping(6)
# Out:
# 12

# %%
import requests  

r = requests.get('http://httpbin.org/get')  
print(type(r.text))  
print(r.json())  
print(type(r.json()))
# Out:
# <class 'str'>
# {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.24.0', 'X-Amzn-Trace-Id': 'Root=1-5ffafc76-5e0455e74d7cbfc4607dae9c'}, 'origin': '112.32.241.87', 'url': 'http://httpbin.org/get'}
# <class 'dict'>

# %%
import requests
import re

r = requests.get('https://maoyan.com/board/4?offset=0').text
r
# Out:
# '<!DOCTYPE html><html lang=en><head><meta charset=utf-8><link href=//p0.meituan.net rel=dns-prefetch><link href=//p1.meituan.net rel=dns-prefetch><link href=//s3plus.meituan.net rel=dns-prefetch><title>猫眼验证中心</title><meta name=keywords content="猫眼验证中心"><meta name=description content="猫眼验证中心"><meta name=applicable-device content=mobile><meta name=viewport content="width=device-width,initial-scale=1,user-scalable=no"><meta name=format-detection content="telephone=no"><meta name=format-detection content="address=no"><meta name=for content=maoyan.com><link rel=icon href=https://e.pipi.cn/overseas/faviconmy.ico type=image/x-icon><script src=https://e.pipi.cn/overseas/polyfill.min.js></script><script>var AppData= {"redirectURL":"https%3A%2F%2Fmaoyan.com%2Fboard%2F4","domain":"maoyan.com","project":"verify","env":"prod"}</script><script crossorigin=anonymous src=//www.dpfile.com/app/owl/static/owl_latest.js></script><script>"use strict";!function(){var e=0<arguments.length&&void 0!==argumen
# ...

# %%
import requests

r = requests.get('https://zhangkaiheng.gitee.io/')
print(type(r.status_code), r.status_code)
print(type(r.headers), r.headers)
print(type(r.cookies), r.cookies)
print(type(r.url), r.url)
print(type(r.history), r.history)
# Out:
# <class 'int'> 200
# <class 'requests.structures.CaseInsensitiveDict'> {'Date': 'Sun, 10 Jan 2021 05:37:16 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'openresty/1.13.6.2', 'Last-Modified': 'Mon, 04 Jan 2021 07:53:48 GMT', 'ETag': 'W/"5ff2c98c-9df5"', 'Expires': 'Mon, 11 Jan 2021 05:37:16 GMT', 'Cache-Control': 'max-age=86400', 'Content-Encoding': 'gzip'}
# <class 'requests.cookies.RequestsCookieJar'> <RequestsCookieJar[]>
# <class 'str'> https://zhangkaiheng.gitee.io/
# <class 'list'> []

# %%
import requests

r = requests.get('https://zhangkaiheng.gitee.io/')
exit() if not r.status_code == requests.codes.ok else print('Request Successfully')
# Out:
# Request Successfully

# %%
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.7.36.5901 Safari/537.36'
}
r = requests.get('https://maoyan.com/board/4?offset=0', headers=headers).text
r
# Out:
# '<!DOCTYPE html>\n\n<!--[if IE 8]><html class="ie8"><![endif]-->\n<!--[if IE 9]><html class="ie9"><![endif]-->\n<!--[if gt IE 9]><!--><html><!--<![endif]-->\n<head>\n  <title>TOP100榜 - 猫眼电影 - 一网打尽好电影</title>\n  \n  <link rel="dns-prefetch" href="//p0.meituan.net"  />\n  <link rel="dns-prefetch" href="//p1.meituan.net"  />\n  <link rel="dns-prefetch" href="//ms0.meituan.net" />\n  <link rel="dns-prefetch" href="//s0.meituan.net" />\n  <link rel="dns-prefetch" href="//ms1.meituan.net" />\n  <link rel="dns-prefetch" href="//analytics.meituan.com" />\n  <link rel="dns-prefetch" href="//report.meituan.com" />\n  <link rel="dns-prefetch" href="//frep.meituan.com" />\n\n  \n  <meta charset="utf-8">\n  <meta name="keywords" content="猫眼电影,电影排行榜,热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100">\n  <meta name="description" content="猫眼电影热门榜单,包括热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100,多维度为用户进行选片决策">\n  <meta http-equiv="cleartype" content="yes" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n  <meta name
# ...

# %%
import requests
try:
    r = requests.get('https://maoyan.com/board/4?offset=0')
    if r.status_code == 200:
        print(r.text)
    print(r.status_code)
except Exception:
    print('你翻车了')
# Out:
# <!DOCTYPE html><html lang=en><head><meta charset=utf-8><link href=//p0.meituan.net rel=dns-prefetch><link href=//p1.meituan.net rel=dns-prefetch><link href=//s3plus.meituan.net rel=dns-prefetch><title>猫眼验证中心</title><meta name=keywords content="猫眼验证中心"><meta name=description content="猫眼验证中心"><meta name=applicable-device content=mobile><meta name=viewport content="width=device-width,initial-scale=1,user-scalable=no"><meta name=format-detection content="telephone=no"><meta name=format-detection content="address=no"><meta name=for content=maoyan.com><link rel=icon href=https://e.pipi.cn/overseas/faviconmy.ico type=image/x-icon><script src=https://e.pipi.cn/overseas/polyfill.min.js></script><script>var AppData= {"redirectURL":"https%3A%2F%2Fmaoyan.com%2Fboard%2F4","domain":"maoyan.com","project":"verify","env":"prod"}</script><script crossorigin=anonymous src=//www.dpfile.com/app/owl/static/owl_latest.js></script><script>"use strict";!function(){var e=0<arguments.length&&void 0!==argument
# ...

# %%
import requests
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.7.36.5901 Safari/537.36'
}
try:
    r = requests.get('https://maoyan.com/board/4?offset=0', headers=headers)
    if r.status_code == 200:
        print(r.text)
except Exception:
    print('你翻车了')
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]><html class="ie8"><![endif]-->
# <!--[if IE 9]><html class="ie9"><![endif]-->
# <!--[if gt IE 9]><!--><html><!--<![endif]-->
# <head>
#   <title>TOP100榜 - 猫眼电影 - 一网打尽好电影</title>
#
#   <link rel="dns-prefetch" href="//p0.meituan.net"  />
#   <link rel="dns-prefetch" href="//p1.meituan.net"  />
#   <link rel="dns-prefetch" href="//ms0.meituan.net" />
#   <link rel="dns-prefetch" href="//s0.meituan.net" />
#   <link rel="dns-prefetch" href="//ms1.meituan.net" />
#   <link rel="dns-prefetch" href="//analytics.meituan.com" />
#   <link rel="dns-prefetch" href="//report.meituan.com" />
#   <link rel="dns-prefetch" href="//frep.meituan.com" />
#
#
#   <meta charset="utf-8">
#   <meta name="keywords" content="猫眼电影,电影排行榜,热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100">
#   <meta name="description" content="猫眼电影热门榜单,包括热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100,多维度为用户进行选片决策">
#   <meta http-equiv="cleartype" content="yes" />
#   <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# ...

# %%
import requests
import re

headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.7.36.5901 Safari/537.36'
}
r = requests.get('https://maoyan.com/board/4?offset=0', headers=headers)

pattern = re.compile('<p class="name"><a href="/films.*?title=".*?" data-act="boarditem-click" data-val=".*?">(.*?)</a></p>', re.S)
titles = re.findall(pattern, r.text)
print(titles)
# Out:
# ['我不是药神', '肖申克的救赎', '绿皮书', '海上钢琴师', '哪吒之魔童降世', '小偷家族', '霸王别姬', '美丽人生', '盗梦空间', '这个杀手不太冷']

# %%
star = re.findall(re.compile('<p class="star">(.*?)</p>', re.S), r)
releasetime = re.findall(re.compile('<p class="releasetime">(.*?)</p>', re.S), r)
top = re.findall(re.compile('<i class="board-index board-index-.*?">(.*?)</i>', re.S), r)

# %%
import requests
import re

headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.7.36.5901 Safari/537.36',
  'Cookie': '__mta=55516948.1610191431899.1610272655288.1610272739280.17; uuid_n_v=v1; uuid=25F1AB40526D11EBBF98AF0FCF9C8DCA707CCB5167C74FC3AEFACED3A88A2C99; _csrf=a4b715dc1631643c9752ef98571cc5e655be6d193a8682dc565399f1923434fe; Hm_lvt_703e94591e87be68cc8da0da7cbd0be2=1610191432; _lxsdk_cuid=176e6e3687ec8-0fddf9dae33fde-9691c21-1fa400-176e6e3687fc8; _lxsdk=25F1AB40526D11EBBF98AF0FCF9C8DCA707CCB5167C74FC3AEFACED3A88A2C99; Hm_lpvt_703e94591e87be68cc8da0da7cbd0be2=1610272739; _lxsdk_s=176ebe5701c-ca3-548-da8%7C%7C1'
}
r = requests.get('https://maoyan.com/board/4?offset=0', headers=headers).text
# print(r)
titles = re.findall(re.compile('<p class="name"><a href="/films/.*?>(.*?)</a>', re.S), r)
star = re.findall(re.compile('<p class="star">(.*?)</p>', re.S), r)
releasetime = re.findall(re.compile('<p class="releasetime">(.*?)</p>', re.S), r)
top = re.findall(re.compile('<i class="board-index board-index-.*?">(.*?)</i>', re.S), r)
img_urls = re.findall(re.compile('<img data-src="(.*?)" alt=".*?" class="board-img" />', re.S), r)
score = re.findall(re.compile('<p class="score"><i class="integer">(.*?)</i><i class="fraction">(.*?)</i></p>', re.S), r)
# scores = []
# for sco in score:
#     a = sco[0] + sco[1]
#     scores.append(a)
scores = [l[0] + l[1] for l in score]
scores
# Out:
# ['9.6', '9.5', '9.5', '9.3', '9.6', '8.1', '9.5', '9.3', '9.0', '9.4']

# %%
import requests
import re

headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.7.36.5901 Safari/537.36',
  'Cookie': '__mta=55516948.1610191431899.1610272655288.1610272739280.17; uuid_n_v=v1; uuid=25F1AB40526D11EBBF98AF0FCF9C8DCA707CCB5167C74FC3AEFACED3A88A2C99; _csrf=a4b715dc1631643c9752ef98571cc5e655be6d193a8682dc565399f1923434fe; Hm_lvt_703e94591e87be68cc8da0da7cbd0be2=1610191432; _lxsdk_cuid=176e6e3687ec8-0fddf9dae33fde-9691c21-1fa400-176e6e3687fc8; _lxsdk=25F1AB40526D11EBBF98AF0FCF9C8DCA707CCB5167C74FC3AEFACED3A88A2C99; Hm_lpvt_703e94591e87be68cc8da0da7cbd0be2=1610272739; _lxsdk_s=176ebe5701c-ca3-548-da8%7C%7C1'
}
r = requests.get('https://maoyan.com/board/4?offset=0', headers=headers).text
# print(r)
titles = re.findall(re.compile('<p class="name"><a href="/films/.*?>(.*?)</a>', re.S), r)
star = re.findall(re.compile('<p class="star">(.*?)</p>', re.S), r)
releasetime = re.findall(re.compile('<p class="releasetime">(.*?)</p>', re.S), r)
top = re.findall(re.compile('<i class="board-index board-index-.*?">(.*?)</i>', re.S), r)
img_urls = re.findall(re.compile('<img data-src="(.*?)" alt=".*?" class="board-img" />', re.S), r)
score = re.findall(re.compile('<p class="score"><i class="integer">(.*?)</i><i class="fraction">(.*?)</i></p>', re.S), r)
# print(score)
scores = [l[0] + l[1] for l in score]
# print(titles, star, releasetime,img_urls,top)
for t, s, r, to, im, sc in zip(titles, star, releasetime, top, img_urls, scores):
    content = [t, s.strip()[3::], r[5::], to, im, sc]
    print(content)
# Out:
# ['我不是药神', '徐峥,周一围,王传君', '2018-07-05', '1', 'https://p0.meituan.net/movie/414176cfa3fea8bed9b579e9f42766b9686649.jpg@160w_220h_1e_1c', '9.6']
# ['肖申克的救赎', '蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿', '1994-09-10(加拿大)', '2', 'https://p0.meituan.net/movie/8112a8345d7f1d807d026282f2371008602126.jpg@160w_220h_1e_1c', '9.5']
# ['绿皮书', '维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼', '2019-03-01', '3', 'https://p1.meituan.net/movie/c9b280de01549fcb71913edec05880585769972.jpg@160w_220h_1e_1c', '9.5']
# ['海上钢琴师', '蒂姆·罗斯,比尔·努恩,克兰伦斯·威廉姆斯三世', '2019-11-15', '4', 'https://p0.meituan.net/movie/609e45bd40346eb8b927381be8fb27a61760914.jpg@160w_220h_1e_1c', '9.3']
# ['哪吒之魔童降世', '吕艳婷,囧森瑟夫,瀚墨', '2019-07-26', '5', 'https://p0.meituan.net/movie/005955214d5b3e50c910d7a511b0cb571445301.jpg@160w_220h_1e_1c', '9.6']
# ['小偷家族', '中川雅也,安藤樱,松冈茉优', '2018-08-03', '6', 'https://p1.meituan.net/movie/ac8f0004928fbce5a038a007b7c73cec746794.jpg@160w_220h_1e_1c', '8.1']
# ...

# %%
import requests
import re

headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.7.36.5901 Safari/537.36',
  'Cookie': '__mta=55516948.1610191431899.1610272655288.1610272739280.17; uuid_n_v=v1; uuid=25F1AB40526D11EBBF98AF0FCF9C8DCA707CCB5167C74FC3AEFACED3A88A2C99; _csrf=a4b715dc1631643c9752ef98571cc5e655be6d193a8682dc565399f1923434fe; Hm_lvt_703e94591e87be68cc8da0da7cbd0be2=1610191432; _lxsdk_cuid=176e6e3687ec8-0fddf9dae33fde-9691c21-1fa400-176e6e3687fc8; _lxsdk=25F1AB40526D11EBBF98AF0FCF9C8DCA707CCB5167C74FC3AEFACED3A88A2C99; Hm_lpvt_703e94591e87be68cc8da0da7cbd0be2=1610272739; _lxsdk_s=176ebe5701c-ca3-548-da8%7C%7C1'
}
r = requests.get('https://maoyan.com/board/4?offset=0', headers=headers).text
# print(r)
titles = re.findall(re.compile('<p class="name"><a href="/films/.*?>(.*?)</a>', re.S), r)
star = re.findall(re.compile('<p class="star">(.*?)</p>', re.S), r)
releasetime = re.findall(re.compile('<p class="releasetime">(.*?)</p>', re.S), r)
top = re.findall(re.compile('<i class="board-index board-index-.*?">(.*?)</i>', re.S), r)
img_urls = re.findall(re.compile('<img data-src="(.*?)" alt=".*?" class="board-img" />', re.S), r)
score = re.findall(re.compile('<p class="score"><i class="integer">(.*?)</i><i class="fraction">(.*?)</i></p>', re.S), r)
# print(score)
scores = [l[0] + l[1] for l in score]
# print(titles, star, releasetime,img_urls,top)
for t, s, r, to, im, sc in zip(titles, star, releasetime, top, img_urls, scores):
    content = [t, s.strip()[3::], r[5::], to, im, sc]
    print(content)
    with open('result.txt','a',encoding ='utf-8') as f:
        f.write(str(content).replace('[', '').replace(']', '').replace('\'', '').replace(', ', ',') + '\n')
        f.close()
# Out:
# ['我不是药神', '徐峥,周一围,王传君', '2018-07-05', '1', 'https://p0.meituan.net/movie/414176cfa3fea8bed9b579e9f42766b9686649.jpg@160w_220h_1e_1c', '9.6']
# ['肖申克的救赎', '蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿', '1994-09-10(加拿大)', '2', 'https://p0.meituan.net/movie/8112a8345d7f1d807d026282f2371008602126.jpg@160w_220h_1e_1c', '9.5']
# ['绿皮书', '维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼', '2019-03-01', '3', 'https://p1.meituan.net/movie/c9b280de01549fcb71913edec05880585769972.jpg@160w_220h_1e_1c', '9.5']
# ['海上钢琴师', '蒂姆·罗斯,比尔·努恩,克兰伦斯·威廉姆斯三世', '2019-11-15', '4', 'https://p0.meituan.net/movie/609e45bd40346eb8b927381be8fb27a61760914.jpg@160w_220h_1e_1c', '9.3']
# ['哪吒之魔童降世', '吕艳婷,囧森瑟夫,瀚墨', '2019-07-26', '5', 'https://p0.meituan.net/movie/005955214d5b3e50c910d7a511b0cb571445301.jpg@160w_220h_1e_1c', '9.6']
# ['小偷家族', '中川雅也,安藤樱,松冈茉优', '2018-08-03', '6', 'https://p1.meituan.net/movie/ac8f0004928fbce5a038a007b7c73cec746794.jpg@160w_220h_1e_1c', '8.1']
# ...

# %%
li = ['我不是药神', '徐峥,周一围,王传君', '2018-07-05', '1', 'https://p0.meituan.net/movie/414176cfa3fea8bed9b579e9f42766b9686649.jpg@160w_220h_1e_1c', '9.6']
str(li)
# Out:
# "['我不是药神', '徐峥,周一围,王传君', '2018-07-05', '1', 'https://p0.meituan.net/movie/414176cfa3fea8bed9b579e9f42766b9686649.jpg@160w_220h_1e_1c', '9.6']"

# %%
import requests
import re
from requests.exceptions import RequestException
 
#猫眼电影网站有反爬虫措施，设置headers后可以爬取
headers = {
  'Content-Type': 'text/plain; charset=UTF-8',
  'Origin':'https://maoyan.com',
  'Referer':'https://maoyan.com/board/4',
  'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36'
}
 
#爬取网页源代码
def get_one_page(url,headers):
  try:
    response =requests.get(url,headers =headers)
    if response.status_code == 200:
      return response.text
    return None
  except RequestsException as e:
    print(e)
    return None
 
#正则表达式提取信息
def parse_one_page(html):
  pattern = re.compile('<dd>.*?board-index.*?>(\d+)</i>.*?data-src="(.*?)".*?name"><a.*?>(.*?)</a>.*?star">(.*?)</p>.*?releasetime">(.*?)</p>.*?integer">(.*?)</i>.*?fraction">(.*?)</i>.*?</dd>',re.S)
  items = re.findall(pattern,html)
  for item in items:
    yield{
    'index':item[0],
    'image':item[1],
    'title':item[2],
    'actor':item[3].strip()[3:],
    'time':item[4].strip()[5:],
    'score':item[5]+item[6]
    }
 
def main():
  url = "https://maoyan.com/board/4"
  html = get_one_page(url,headers)
  for item in parse_one_page(html):
    print(item)
 
if __name__ == '__main__':
  main()

# %%
#-*-coding:utf-8-*-
import requests
import re
from requests.exceptions import RequestException
 
#猫眼电影网站有反爬虫措施，设置headers后可以爬取
headers = {
  'Content-Type': 'text/plain; charset=UTF-8',
  'Origin':'https://maoyan.com',
  'Referer':'https://maoyan.com/board/4',
  'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36'
}
 
#爬取网页源代码
def get_one_page(url,headers):
  try:
    response =requests.get(url,headers =headers)
    if response.status_code == 200:
      return response.text
    return None
  except RequestsException:
    return None
 
#正则表达式提取信息
def parse_one_page(html):
  pattern = re.compile('<dd>.*?board-index.*?>(\d+)</i>.*?data-src="(.*?)".*?name"><a.*?>(.*?)</a>.*?star">(.*?)</p>.*?releasetime">(.*?)</p>.*?integer">(.*?)</i>.*?fraction">(.*?)</i>.*?</dd>',re.S)
  items = re.findall(pattern,html)
  for item in items:
    yield{
    'index':item[0],
    'image':item[1],
    'title':item[2],
    'actor':item[3].strip()[3:],
    'time':item[4].strip()[5:],
    'score':item[5]+item[6]
    }
 
def main():
  url = "https://maoyan.com/board/4"
  html = get_one_page(url,headers)
  for item in parse_one_page(html):
    print(item)
 
if __name__ == '__main__':
  main()
# Out:
# {'index': '1', 'image': 'https://p0.meituan.net/movie/414176cfa3fea8bed9b579e9f42766b9686649.jpg@160w_220h_1e_1c', 'title': '我不是药神', 'actor': '徐峥,周一围,王传君', 'time': '2018-07-05', 'score': '9.6'}
# {'index': '2', 'image': 'https://p0.meituan.net/movie/8112a8345d7f1d807d026282f2371008602126.jpg@160w_220h_1e_1c', 'title': '肖申克的救赎', 'actor': '蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿', 'time': '1994-09-10(加拿大)', 'score': '9.5'}
# {'index': '3', 'image': 'https://p1.meituan.net/movie/c9b280de01549fcb71913edec05880585769972.jpg@160w_220h_1e_1c', 'title': '绿皮书', 'actor': '维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼', 'time': '2019-03-01', 'score': '9.5'}
# {'index': '4', 'image': 'https://p0.meituan.net/movie/609e45bd40346eb8b927381be8fb27a61760914.jpg@160w_220h_1e_1c', 'title': '海上钢琴师', 'actor': '蒂姆·罗斯,比尔·努恩,克兰伦斯·威廉姆斯三世', 'time': '2019-11-15', 'score': '9.3'}
# ...

# %%
#-*-coding:utf-8-*-
import requests
import re
import json
import os
from requests.exceptions import RequestException
from  multiprocessing import Pool

headers = {
  'Content-Type': 'text/plain; charset=UTF-8',
  'Origin':'https://maoyan.com',
  'Referer':'https://maoyan.com/board/4',
  'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36'
}
 

def get_one_page(url,headers):
  try:
    response =requests.get(url,headers =headers)
    if response.status_code == 200:
      return response.text
    return None
  except RequestException:
    return None
 
def parse_one_page(html):
  pattern = re.compile('<dd>.*?board-index.*?>(\d+)</i>.*?data-src="(.*?)".*?name"><a.*?>(.*?)</a>.*?star">(.*?)</p>.*?releasetime">(.*?)</p>.*?integer">(.*?)</i>.*?fraction">(.*?)</i>.*?</dd>',re.S)
  items = re.findall(pattern,html)
  for item in items:
    yield{
    'index':item[0],
    'image':item[1],
    'title':item[2],
    'actor':item[3].strip()[3:],
    'time':item[4].strip()[5:],
    'score':item[5]+item[6]
    }

def write_to_file(content):
  #encoding ='utf-8',ensure_ascii =False,使写入文件的代码显示为中文
  with open('result.txt','a',encoding ='utf-8') as f:
    f.write(json.dumps(content,ensure_ascii =False)+'\n')
    f.close()
    
def save_image_file(url,path): 
  jd = requests.get(url)
  if jd.status_code == 200:
    with open(path,'wb') as f:
      f.write(jd.content)
      f.close()
 
def main(offset):
  url = "https://maoyan.com/board/4?offset="+str(offset)
  html = get_one_page(url,headers)
  if not os.path.exists('covers'):
    os.mkdir('covers')
  for item in parse_one_page(html):
    print(item)
    write_to_file(item)
    save_image_file(item['image'],'covers/'+item['title']+'.jpg')
 
if __name__ == '__main__':
#     for i in range(10):
#         main(i*10)
  pool = Pool()
  pool.map(main,[i*10 for i in range(10)])
  pool.close()
  pool.join()
